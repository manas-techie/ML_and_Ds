# %%
import logging

## create a logger for mmodule 1
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)


## create a logger for module 2
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.INFO)  


logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',  
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
##log message with different loggers
logger1.debug("This is a debug message from module 1")
logger2.info("This is an info message from module 2")
logger1.warning("This is a warning message from module 1")
# Out:
# 2026-02-22 00:52:51 - module1 - DEBUG - This is a debug message from module 1
# 2026-02-22 00:52:51 - module2 - INFO - This is an info message from module 2
# 2026-02-22 00:52:51 - module1 - WARNING - This is a warning message from module 1
